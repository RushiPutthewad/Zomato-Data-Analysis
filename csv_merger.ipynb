# %% [markdown]
# # CSV Files Merger
# This notebook recursively searches through folders and merges all CSV files with '|' delimiter into a single file.

# %%
import pandas as pd
import os
from pathlib import Path

# %%
def merge_csv_files(root_directory, output_file):
    """
    Recursively merge all CSV files with '|' delimiter from subdirectories
    """
    all_dataframes = []
    processed_files = 0
    error_files = []
    
    print(f"Starting to process CSV files from: {root_directory}")
    
    # Walk through all directories and subdirectories
    for root, dirs, files in os.walk(root_directory):
        csv_files = [f for f in files if f.endswith('.csv')]
        
        if csv_files:
            print(f"\nProcessing {len(csv_files)} CSV files in: {root}")
            
        for file in csv_files:
            file_path = os.path.join(root, file)
            try:
                # Read CSV with pipe delimiter
                df = pd.read_csv(file_path, delimiter='|')
                
                # Skip empty dataframes
                if not df.empty:
                    all_dataframes.append(df)
                    processed_files += 1
                    
                    if processed_files % 100 == 0:
                        print(f"  Processed {processed_files} files...")
                        
            except Exception as e:
                error_files.append((file_path, str(e)))
                print(f"  Error reading {file}: {e}")
    
    # Report results
    print(f"\n=== Processing Summary ===")
    print(f"Successfully processed: {processed_files} files")
    print(f"Errors encountered: {len(error_files)} files")
    
    if error_files:
        print("\nFiles with errors:")
        for file_path, error in error_files[:5]:  # Show first 5 errors
            print(f"  {file_path}: {error}")
        if len(error_files) > 5:
            print(f"  ... and {len(error_files) - 5} more")
    
    if all_dataframes:
        print(f"\nMerging {len(all_dataframes)} dataframes...")
        
        # Concatenate all dataframes
        merged_df = pd.concat(all_dataframes, ignore_index=True)
        
        # Save merged data with pipe delimiter
        merged_df.to_csv(output_file, sep='|', index=False)
        
        print(f"\n=== Merge Completed! ===")
        print(f"Total rows in merged file: {len(merged_df):,}")
        print(f"Total columns: {len(merged_df.columns)}")
        print(f"Output saved to: {output_file}")
        
        return merged_df
    else:
        print("No valid CSV files found to merge!")
        return None

# %%
# Set paths
root_dir = r"d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data"
output_path = r"d:\Backup balaji Puttewad\C Drive\Zomato\merged_zomato_data.csv"

# Run merge
merged_data = merge_csv_files(root_dir, output_path)
# Out:
# Starting to process CSV files from: d:\Backup balaji Puttewad\C Drive\Zomato
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato
#
# Processing 60 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Agra
#
# Processing 175 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Ahmedabad
#   Processed 100 files...
#   Processed 200 files...
#
# Processing 18 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Ajmer
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Alappuzha
#
# Processing 25 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Allahabad
#
# Processing 13 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Amravati
#
# Processing 36 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Amritsar
#   Processed 300 files...
#
# Processing 54 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Aurangabad
#
# Processing 568 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Bengaluru
#   Processed 400 files...
#   Processed 500 files...
#   Processed 600 files...
#   Processed 700 files...
#   Processed 800 files...
#   Processed 900 files...
#
# Processing 86 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Bhopal
#   Processed 1000 files...
#
# Processing 72 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Bhubaneswar
#   Processed 1100 files...
#
# Processing 145 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Chandigarh
#   Processed 1200 files...
#
# Processing 323 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Chennai
#   Processed 1300 files...
#   Processed 1400 files...
#   Processed 1500 files...
#
# Processing 71 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Coimbatore
#   Processed 1600 files...
#
# Processing 13 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Cuttack
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Darjeeling
#
# Processing 54 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Dehradun
#   Processed 1700 files...
#
# Processing 1308 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Delhi NCR
#   Processed 1800 files...
#   Processed 1900 files...
#   Processed 2000 files...
#   Processed 2100 files...
#   Processed 2200 files...
#   Processed 2300 files...
#   Processed 2400 files...
#   Processed 2500 files...
#   Processed 2600 files...
#   Processed 2700 files...
#   Processed 2800 files...
#   Processed 2900 files...
#   Processed 3000 files...
#
# Processing 4 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Dharamshala
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Gangtok
#
# Processing 61 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Goa
#
# Processing 16 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Gorakhpur
#   Processed 3100 files...
#
# Processing 14 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Guntur
#
# Processing 48 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Guwahati
#
# Processing 36 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Gwalior
#   Processed 3200 files...
#
# Processing 14 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Haridwar
#
# Processing 351 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Hyderabad
#   Processed 3300 files...
#   Processed 3400 files...
#   Processed 3500 files...
#
# Processing 109 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Indore
#   Processed 3600 files...
#
# Processing 28 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jabalpur
#   Processed 3700 files...
#
# Processing 174 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jaipur
#   Processed 3800 files...
#
# Processing 33 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jalandhar
#   Processed 3900 files...
#
# Processing 20 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jammu
#
# Processing 11 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jamnagar
#
# Processing 20 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jamshedpur
#
# Processing 21 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jhansi
#
# Processing 36 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Jodhpur
#   Processed 4000 files...
#
# Processing 56 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Kanpur
#
# Processing 70 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Kochi
#   Processed 4100 files...
#
# Processing 19 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Kolhapur
#
# Processing 288 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Kolkata
#   Processed 4200 files...
#   Processed 4300 files...
#   Processed 4400 files...
#
# Processing 39 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Kota
#
# Processing 123 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Lucknow
#   Processed 4500 files...
#   Processed 4600 files...
#
# Processing 85 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Ludhiana
#
# Processing 25 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Madurai
#   Processed 4700 files...
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Manali
#
# Processing 32 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Mangalore
#
# Processing 18 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Manipal
#
# Processing 25 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Meerut
#   Processed 4800 files...
#
# Processing 943 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Mumbai
#   Processed 4900 files...
#   Processed 5000 files...
#   Processed 5100 files...
#   Processed 5200 files...
#   Processed 5300 files...
#   Processed 5400 files...
#   Processed 5500 files...
#   Processed 5600 files...
#   Processed 5700 files...
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Mussoorie
#
# Processing 29 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Mysore
#
# Processing 113 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Nagpur
#   Processed 5800 files...
#
# Processing 3 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Nainital
#
# Processing 53 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Nashik
#   Processed 5900 files...
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Neemrana
#
# Processing 5 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Ooty
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Palakkad
#
# Processing 27 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Patiala
#
# Processing 46 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Patna
#   Processed 6000 files...
#
# Processing 23 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Puducherry
#
# Processing 504 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Pune
#   Processed 6100 files...
#   Processed 6200 files...
#   Processed 6300 files...
#   Processed 6400 files...
#   Processed 6500 files...
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Pushkar
#
# Processing 55 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Raipur
#   Processed 6600 files...
#
# Processing 28 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Rajkot
#
# Processing 44 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Ranchi
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Rishikesh
#
# Processing 10 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Salem
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Shimla
#
# Processing 12 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Siliguri
#   Processed 6700 files...
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Srinagar
#
# Processing 70 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Surat
#
# Processing 13 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Thrissur
#
# Processing 11 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Tirupati
#
# Processing 15 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Trichy
#   Processed 6800 files...
#
# Processing 21 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Trivandrum
#
# Processing 50 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Udaipur
#
# Processing 86 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Vadodara
#   Processed 6900 files...
#
# Processing 37 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Varanasi
#   Processed 7000 files...
#
# Processing 10 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Vellore
#
# Processing 24 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Vijayawada
#
# Processing 44 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\Visakhapatnam
#
# Processing 60 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Agra
#   Processed 7100 files...
#
# Processing 175 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Ahmedabad
#   Processed 7200 files...
#   Processed 7300 files...
#
# Processing 18 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Ajmer
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Alappuzha
#
# Processing 25 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Allahabad
#
# Processing 13 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Amravati
#
# Processing 36 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Amritsar
#   Processed 7400 files...
#
# Processing 54 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Aurangabad
#
# Processing 568 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Bengaluru
#   Processed 7500 files...
#   Processed 7600 files...
#   Processed 7700 files...
#   Processed 7800 files...
#   Processed 7900 files...
#   Processed 8000 files...
#
# Processing 86 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Bhopal
#   Processed 8100 files...
#
# Processing 72 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Bhubaneswar
#
# Processing 145 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Chandigarh
#   Processed 8200 files...
#   Processed 8300 files...
#
# Processing 323 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Chennai
#   Processed 8400 files...
#   Processed 8500 files...
#   Processed 8600 files...
#
# Processing 71 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Coimbatore
#   Processed 8700 files...
#
# Processing 13 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Cuttack
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Darjeeling
#
# Processing 54 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Dehradun
#
# Processing 1308 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Delhi NCR
#   Processed 8800 files...
#   Processed 8900 files...
#   Processed 9000 files...
#   Processed 9100 files...
#   Processed 9200 files...
#   Processed 9300 files...
#   Processed 9400 files...
#   Processed 9500 files...
#   Processed 9600 files...
#   Processed 9700 files...
#   Processed 9800 files...
#   Processed 9900 files...
#   Processed 10000 files...
#   Processed 10100 files...
#
# Processing 4 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Dharamshala
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Gangtok
#
# Processing 61 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Goa
#
# Processing 16 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Gorakhpur
#
# Processing 14 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Guntur
#   Processed 10200 files...
#
# Processing 48 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Guwahati
#
# Processing 36 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Gwalior
#
# Processing 14 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Haridwar
#   Processed 10300 files...
#
# Processing 351 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Hyderabad
#   Processed 10400 files...
#   Processed 10500 files...
#   Processed 10600 files...
#
# Processing 109 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Indore
#   Processed 10700 files...
#
# Processing 28 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jabalpur
#
# Processing 174 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jaipur
#   Processed 10800 files...
#   Processed 10900 files...
#
# Processing 33 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jalandhar
#
# Processing 20 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jammu
#   Processed 11000 files...
#
# Processing 11 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jamnagar
#
# Processing 20 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jamshedpur
#
# Processing 21 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jhansi
#
# Processing 36 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Jodhpur
#   Processed 11100 files...
#
# Processing 56 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Kanpur
#
# Processing 70 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Kochi
#   Processed 11200 files...
#
# Processing 19 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Kolhapur
#
# Processing 288 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Kolkata
#   Processed 11300 files...
#   Processed 11400 files...
#   Processed 11500 files...
#
# Processing 39 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Kota
#
# Processing 123 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Lucknow
#   Processed 11600 files...
#
# Processing 85 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Ludhiana
#   Processed 11700 files...
#
# Processing 25 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Madurai
#   Processed 11800 files...
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Manali
#
# Processing 32 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Mangalore
#
# Processing 18 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Manipal
#
# Processing 25 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Meerut
#
# Processing 943 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Mumbai
#   Processed 11900 files...
#   Processed 12000 files...
#   Processed 12100 files...
#   Processed 12200 files...
#   Processed 12300 files...
#   Processed 12400 files...
#   Processed 12500 files...
#   Processed 12600 files...
#   Processed 12700 files...
#   Processed 12800 files...
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Mussoorie
#
# Processing 29 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Mysore
#
# Processing 113 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Nagpur
#   Processed 12900 files...
#
# Processing 3 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Nainital
#
# Processing 53 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Nashik
#   Processed 13000 files...
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Neemrana
#
# Processing 5 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Ooty
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Palakkad
#
# Processing 27 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Patiala
#
# Processing 46 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Patna
#   Processed 13100 files...
#
# Processing 23 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Puducherry
#
# Processing 504 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Pune
#   Processed 13200 files...
#   Processed 13300 files...
#   Processed 13400 files...
#   Processed 13500 files...
#   Processed 13600 files...
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Pushkar
#
# Processing 55 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Raipur
#
# Processing 28 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Rajkot
#   Processed 13700 files...
#
# Processing 44 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Ranchi
#
# Processing 1 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Rishikesh
#
# Processing 10 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Salem
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Shimla
#
# Processing 12 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Siliguri
#
# Processing 2 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Srinagar
#
# Processing 70 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Surat
#   Processed 13800 files...
#
# Processing 13 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Thrissur
#
# Processing 11 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Tirupati
#
# Processing 15 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Trichy
#
# Processing 21 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Trivandrum
#   Processed 13900 files...
#
# Processing 50 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Udaipur
#
# Processing 86 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Vadodara
#   Processed 14000 files...
#
# Processing 37 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Varanasi
#
# Processing 10 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Vellore
#   Processed 14100 files...
#
# Processing 24 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Vijayawada
#
# Processing 44 CSV files in: d:\Backup balaji Puttewad\C Drive\Zomato\zomato_data\Visakhapatnam
#
# === Processing Summary ===
# Successfully processed: 14171 files
# Errors encountered: 0 files
#
# Merging 14171 dataframes...
#
# === Merge Completed! ===
# Total rows in merged file: 422,492
# Total columns: 12
# Output saved to: d:\Backup balaji Puttewad\C Drive\Zomato\merged_zomato_data.csv

# %%
# Display basic information about the merged dataset
if merged_data is not None:
    print("Dataset Info:")
    print(f"Shape: {merged_data.shape}")
    print(f"\nColumns: {list(merged_data.columns)}")
    print(f"\nFirst few rows:")
    display(merged_data.head())
    
    print(f"\nData types:")
    print(merged_data.dtypes)
    
    print(f"\nUnique cities: {merged_data['CITY'].nunique() if 'CITY' in merged_data.columns else 'N/A'}")
    if 'CITY' in merged_data.columns:
        print(f"Cities: {sorted(merged_data['CITY'].unique())}")
# Out:
# Dataset Info:
# Shape: (422492, 12)
#
# Columns: ['NAME', 'PRICE', 'CUSINE_CATEGORY', 'CITY', 'REGION', 'URL', 'PAGE NO', 'CUSINE TYPE', 'TIMING', 'RATING_TYPE', 'RATING', 'VOTES']
#
# First few rows:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# 2  https://www.zomato.com/agra/bikanervala-khanda...        1    Quick Bites
# 3  https://www.zomato.com/agra/mama-chicken-mama-...        1    Quick Bites
# 4  https://www.zomato.com/agra/honeydew-restauran...        1    Quick Bites
#
#                                             TIMING RATING_TYPE RATING VOTES
# 0                        1130am to 1130pm(Mon-Sun)   Excellent    4.8   273
# 1                           730am to 11pm(Mon-Sun)   Very Good    4.3   554
# 2                             8am to 11pm(Mon-Sun)   Very Good    4.4   645
# 3      1230pm to 12midnight(Mon,Wed,Thu,Fri,Sat...   Very Good    4.3   894
# 4  11am to 1035pm(Mon,Tue,Wed,Fri,Sat),11am to ...   Very Good    4.1   489
# Data types:
# NAME               object
# PRICE               int64
# CUSINE_CATEGORY    object
# CITY               object
# REGION             object
# URL                object
# PAGE NO             int64
# CUSINE TYPE        object
# TIMING             object
# RATING_TYPE        object
# RATING             object
# VOTES              object
# dtype: object
#
# Unique cities: 81
# Cities: ['Agra', 'Ahmedabad', 'Ajmer', 'Alappuzha', 'Allahabad', 'Amravati', 'Amritsar', 'Aurangabad', 'Bengaluru', 'Bhopal', 'Bhubaneswar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Cuttack', 'Darjeeling', 'Dehradun', 'Delhi NCR', 'Dharamshala', 'Gangtok', 'Goa', 'Gorakhpur', 'Guntur', 'Guwahati', 'Gwalior', 'Haridwar', 'Hyderabad', 'Indore', 'Jabalpur', 'Jaipur', 'Jalandhar', 'Jammu', 'Jamnagar', 'Jamshedpur', 'Jhansi', 'Jodhpur', 'Kanpur', 'Kochi', 'Kolhapur', 'Kolkata', 'Kota', 'Lucknow', 'Ludhiana', 'Madurai', 'Manali', 'Mangalore', 'Manipal', 'Meerut', 'Mumbai', 'Mussoorie', 'Mysore', 'Nagpur', 'Nainital', 'Nashik', 'Neemrana', 'Ooty', 'Palakkad', 'Patiala', 'Patna', 'Puducherry', 'Pune', 'Pushkar', 'Raipur', 'Rajkot', 'Ranchi', 'Rishikesh', 'Salem', 'Shimla', 'Siliguri', 'Srinagar', 'Surat', 'Thrissur', 'Tirupati', 'Trichy', 'Trivandrum', 'Udaipur', 'Vadodara', 'Varanasi', 'Vellore', 'Vijayawada', 'Visakhapatnam']

# %%
# Optional: Check for any data quality issues
if merged_data is not None:
    print("Data Quality Check:")
    print(f"\nMissing values per column:")
    missing_data = merged_data.isnull().sum()
    print(missing_data[missing_data > 0])
    
    print(f"\nDuplicate rows: {merged_data.duplicated().sum()}")
    
    # Check file size
    file_size = os.path.getsize(output_path) / (1024 * 1024)  # MB
    print(f"\nOutput file size: {file_size:.2f} MB")
# Out:
# Data Quality Check:
#
# Missing values per column:
# CUSINE_CATEGORY      260
# TIMING              2564
# RATING_TYPE        42152
# dtype: int64
#
# Duplicate rows: 285219
#
# Output file size: 73.98 MB
